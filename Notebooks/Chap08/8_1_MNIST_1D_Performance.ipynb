# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/pb/l9m9zb4d3dl_hpzdkkks2pz40000gn/T/pip-req-build-v0mzrmkl
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/pb/l9m9zb4d3dl_hpzdkkks2pz40000gn/T/pip-req-build-v0mzrmkl
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting requests (from mnist1d==0.0.2.post16)
#   Downloading requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: numpy in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from mnist1d==0.0.2.post16) (2.5.3)
# Requirement already satisfied: matplotlib in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from mnist1d==0.0.2.post16) (3.11.2)
# Collecting scipy (from mnist1d==0.0.2.post16)
#   Downloading scipy-1.18.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (62 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.65.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (26.3)
# Requirement already satisfied: pillow>=9 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/miraj/git/udlbook/.pixi/envs/default/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Collecting charset_normalizer<4,>=2 (from requests->mnist1d==0.0.2.post16)
#   Downloading charset_normalizer-3.5.1-cp314-cp314-macosx_10_15_universal2.whl.metadata (45 kB)
# Collecting idna<4,>=2.5 (from requests->mnist1d==0.0.2.post16)
#   Downloading idna-3.20-py3-none-any.whl.metadata (7.2 kB)
# Collecting urllib3<3,>=1.26 (from requests->mnist1d==0.0.2.post16)
#   Downloading urllib3-2.8.0-py3-none-any.whl.metadata (7.4 kB)
# Collecting certifi>=2023.5.7 (from requests->mnist1d==0.0.2.post16)
#   Downloading certifi-2026.7.22-py3-none-any.whl.metadata (2.5 kB)
# Downloading requests-2.34.2-py3-none-any.whl (73 kB)
# Downloading charset_normalizer-3.5.1-cp314-cp314-macosx_10_15_universal2.whl (341 kB)
# Downloading idna-3.20-py3-none-any.whl (69 kB)
# Downloading urllib3-2.8.0-py3-none-any.whl (135 kB)
# Downloading certifi-2026.7.22-py3-none-any.whl (136 kB)
# Downloading scipy-1.18.1-cp314-cp314-macosx_14_0_arm64.whl (20.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.5/20.5 MB 9.2 MB/s  0:00:02 eta 0:00:01m
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=3a27674a9a563e9dec27a4123cba24f1e2a8a634c2d2354036300c5a736ea22d
#   Stored in directory: /private/var/folders/pb/l9m9zb4d3dl_hpzdkkks2pz40000gn/T/pip-ephem-wheel-cache-tokquiqn/wheels/a7/5e/c1/60c7abea08f623f6e2a8228323d8fb65232fbee3158b4a37b7
# Successfully built mnist1d
# Installing collected packages: urllib3, scipy, idna, charset_normalizer, certifi, requests, mnist1d
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [mnist1d]m1/7 [scipy]
# Successfully installed certifi-2026.7.22 charset_normalizer-3.5.1 idna-3.20 mnist1d-0.0.2.post16 requests-2.34.2 scipy-1.18.1 urllib3-2.8.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100  # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
  );


def weights_init(layer_in):
  # TODO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_normal_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)
print("Initializing layer")



# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.575597, train error 60.22,  test loss 1.665148, test error 64.80
# Epoch     1, train loss 1.289364, train error 45.58,  test loss 1.426245, test error 53.10
# Epoch     2, train loss 1.124340, train error 40.88,  test loss 1.309076, test error 50.60
# Epoch     3, train loss 1.021333, train error 36.05,  test loss 1.279400, test error 47.50
# Epoch     4, train loss 0.844935, train error 28.95,  test loss 1.119072, test error 41.50
# Epoch     5, train loss 0.734675, train error 25.18,  test loss 1.069821, test error 41.30
# Epoch     6, train loss 0.681180, train error 23.35,  test loss 1.149212, test error 40.80
# Epoch     7, train loss 0.573055, train error 19.22,  test loss 1.064252, test error 39.80
# Epoch     8, train loss 0.513988, train error 17.03,  test loss 1.048599, test error 39.60
# Epoch     9, train loss 0.455729, train error 15.15,  test loss 1.024092, test error 37.10
# Epoch    10, train loss 0.356288, train error 9.60,  test loss 1.007997, test error 35.80
# Epoch    11, train loss 0.340150, train error 10.32,  test loss 1.044007, test error 36.00
# Epoch    12, train loss 0.298515, train error 7.88,  test loss 1.038365, test error 34.50
# Epoch    13, train loss 0.268366, train error 6.15,  test loss 1.034510, test error 34.70
# Epoch    14, train loss 0.261267, train error 6.90,  test loss 1.080904, test error 35.60
# Epoch    15, train loss 0.236767, train error 5.72,  test loss 1.084931, test error 35.50
# Epoch    16, train loss 0.194088, train error 3.85,  test loss 1.077488, test error 33.60
# Epoch    17, train loss 0.179475, train error 3.18,  test loss 1.079945, test error 33.50
# Epoch    18, train loss 0.169688, train error 3.15,  test loss 1.134292, test error 34.50
# Epoch    19, train loss 0.152510, train error 2.22,  test loss 1.129854, test error 34.80
# Epoch    20, train loss 0.129686, train error 1.15,  test loss 1.107011, test error 33.50
# Epoch    21, train loss 0.123824, train error 0.93,  test loss 1.146425, test error 33.50
# Epoch    22, train loss 0.116582, train error 0.80,  test loss 1.152108, test error 34.70
# Epoch    23, train loss 0.109578, train error 0.55,  test loss 1.162054, test error 34.60
# Epoch    24, train loss 0.103988, train error 0.65,  test loss 1.163091, test error 34.30
# Epoch    25, train loss 0.098487, train error 0.47,  test loss 1.171854, test error 34.30
# Epoch    26, train loss 0.095486, train error 0.40,  test loss 1.194477, test error 34.40
# Epoch    27, train loss 0.090406, train error 0.38,  test loss 1.201424, test error 34.30
# Epoch    28, train loss 0.086425, train error 0.25,  test loss 1.207253, test error 34.30
# Epoch    29, train loss 0.081842, train error 0.20,  test loss 1.221398, test error 34.50
# Epoch    30, train loss 0.078611, train error 0.22,  test loss 1.219065, test error 34.70
# Epoch    31, train loss 0.075953, train error 0.18,  test loss 1.227308, test error 34.50
# Epoch    32, train loss 0.074171, train error 0.18,  test loss 1.235745, test error 34.80
# Epoch    33, train loss 0.072783, train error 0.15,  test loss 1.241973, test error 34.90
# Epoch    34, train loss 0.070959, train error 0.15,  test loss 1.246157, test error 34.10
# Epoch    35, train loss 0.069464, train error 0.12,  test loss 1.247905, test error 34.70
# Epoch    36, train loss 0.068212, train error 0.10,  test loss 1.257481, test error 34.50
# Epoch    37, train loss 0.066655, train error 0.10,  test loss 1.256264, test error 34.70
# Epoch    38, train loss 0.065279, train error 0.10,  test loss 1.265620, test error 34.40
# Epoch    39, train loss 0.063541, train error 0.10,  test loss 1.270527, test error 34.60
# Epoch    40, train loss 0.062813, train error 0.07,  test loss 1.274380, test error 34.50
# Epoch    41, train loss 0.062061, train error 0.07,  test loss 1.278049, test error 34.40
# Epoch    42, train loss 0.061428, train error 0.10,  test loss 1.276596, test error 34.60
# Epoch    43, train loss 0.060791, train error 0.05,  test loss 1.279706, test error 34.60
# Epoch    44, train loss 0.060207, train error 0.05,  test loss 1.283073, test error 34.60
# Epoch    45, train loss 0.059503, train error 0.10,  test loss 1.286605, test error 34.70
# Epoch    46, train loss 0.058966, train error 0.05,  test loss 1.288620, test error 34.60
# Epoch    47, train loss 0.058496, train error 0.05,  test loss 1.291374, test error 34.60
# Epoch    48, train loss 0.057772, train error 0.05,  test loss 1.293541, test error 34.70
# Epoch    49, train loss 0.057259, train error 0.05,  test loss 1.295320, test error 34.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TODO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
